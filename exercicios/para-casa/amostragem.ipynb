# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
caminho_imagens = [
    r'C:\\Users\\info2\\OneDrive\\Documentos\\escolaridade.png',
    r'C:\\Users\\info2\\Downloads\Amostragem - Escolaridadde.png'
]

# %%
imagens = [cv2.imread(caminho_imagens) for caminho_imagens in caminho_imagens]

# %%
num_imagens = len(imagens)
sample_size = 3

# %%
sample_size = 3

# %%
if sample_size > num_imagens:
    print(f"O tamanho da amostra ({sample_size}) é maior que o número de imagens disponíveis ({num_imagens}). Ajustando o tamanho da amostra para {num_imagens}.")
    sample_size = num_imagens
# Out:
# O tamanho da amostra (3) é maior que o número de imagens disponíveis (2). Ajustando o tamanho da amostra para 2.

# %%
sampled_images = random.sample(images, sample_size)

# %%
plt.figure(figsize=(15, 5))

for i, img in enumerate(sampled_images):
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Converter BGR para RGB para exibição correta com matplotlib
    plt.subplot(1, sample_size, i + 1)
    plt.imshow(img_rgb)
    plt.title(f'Amostra {i+1}')
    plt.axis('off')

plt.show()

# %% [markdown]
# ## Com essa amostragem, podemos perceber que a maioria das respondentes possuem entre Superior Incompleto e Superior Completo, o que já é mais da maioria da população brasileira. Porém, em que condições mentais essas respondentes chegaram nesse nível de escolaridade? Outro ponto que podemos pensar, numa segunda amostra, é: qual a raça e posição social das respondentes? Sabendo que esses dois pontos são de extrema relevância no mundo mas, principalmente, num país como o Brasil.
#
# ## Todos esses pontos influenciam na vida de uma mulher lésbica perante a sociedade, pois na maioria das vezes, essa mulher está escondida, "no armário", ou vivendo situação de abuso. Infelizmente não temos dados sobre isso, e o pouco que temos, não abraça uma grande porcentagem dessas mulheres. O que sabemos dessas vivências, é discutido em rodas de conversas, ambientes exclusivos e lugares que reforçam a ideia de grupo de acolhimento.
#
# ## Sabemos que numa sociedade racista, machista e lesbofóbica (LGBTfóbica), a chance de uma mulher lésbica se sobresair no ambiente escolar e profissional diminui drasticamente, e é exatamente por isso que esse tipo de estudo é tão necessário, para que as próximas gerações entendam como a sociedade nos vê e como a mesma pode nos ajudar. Programas sociais, doações e visibilidade são de extrema importância para entendermos a fundo esses números e, mais do que isso, olhar pros outros números que menos escolaridade (e que não são poucos).
#
# **Amostragem realizada com os dados:**
# ***1º gráfico***: Coletagem de respostas através de formulário online próprio (55 respondentes)
# ***2º gráfico***: Coletagem de respostas através dos Lesbocenso 2022 (25mil+ respondentes)
# *Ambas pesquisas com coletagem anônima*
