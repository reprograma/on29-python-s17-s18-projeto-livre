# %%
file_path_enem = 'DADOS/MICRODADOS_ENEM_2023.csv'

# %%
lista_col = ['NU_INSCRICAO','TP_FAIXA_ETARIA','TP_SEXO','TP_ESTADO_CIVIL','TP_COR_RACA','TP_ANO_CONCLUIU','TP_ESCOLA','TP_ENSINO','SG_UF_ESC','TP_DEPENDENCIA_ADM_ESC','TP_LOCALIZACAO_ESC','TP_PRESENCA_CN','TP_PRESENCA_CH','TP_PRESENCA_LC','TP_PRESENCA_MT','NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO']

# %%
colunas_drop = ['NU_ANO','TP_ESTADO_CIVIL','TP_NACIONALIDADE', 'TP_ST_CONCLUSAO','IN_TREINEIRO',  'CO_MUNICIPIO_ESC','NO_MUNICIPIO_ESC','CO_UF_ESC','TP_SIT_FUNC_ESC',
                'CO_MUNICIPIO_PROVA','NO_MUNICIPIO_PROVA','CO_UF_PROVA','SG_UF_PROVA','CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC', 'CO_PROVA_MT', 'TX_RESPOSTAS_CN','TX_RESPOSTAS_CH','TX_RESPOSTAS_LC',
                'TX_RESPOSTAS_MT','TP_LINGUA','TX_GABARITO_CN','TX_GABARITO_CH','TX_GABARITO_LC','TX_GABARITO_MT','TP_STATUS_REDACAO','NU_NOTA_COMP1','NU_NOTA_COMP2','NU_NOTA_COMP3','NU_NOTA_COMP4','NU_NOTA_COMP5',
                'Q001','Q002','Q003','Q004','Q005','Q006','Q007','Q008','Q009','Q010','Q011','Q012','Q013','Q014','Q015','Q016','Q017','Q018','Q019','Q020','Q021','Q022','Q023','Q024','Q025'         
]

# %%
replace_columns={
    'NU_INSCRICAO': 'Número de inscrição',
    'TP_FAIXA_ETARIA': 'Faixa etária',
    'TP_SEXO': 'Sexo',
    'TP_COR_RACA': 'Cor/raça',
    'TP_ANO_CONCLUIU': 'Ano de Conclusão do Ensino Médio',
    'TP_ESCOLA': 'Tipo de escola do Ensino Médio',
    'TP_ENSINO': 'Tipo de ensino',
    'SG_UF_ESC': 'Sigla da Unidade da Federação da escola',
    'TP_DEPENDENCIA_ADM_ESC': 'Dependência administrativa (Escola)',
    'TP_LOCALIZACAO_ESC': 'Localização (Escola)',
    'TP_PRESENCA_CN': 'Presença Ciências da Natureza',
    'TP_PRESENCA_CH': 'Presença Ciências Humanas',
    'TP_PRESENCA_LC': 'Presença Linguagens e Códigos',
    'TP_PRESENCA_MT': 'Presença Matemática',
    'NU_NOTA_CN': 'Nota Ciências da Natureza',
    'NU_NOTA_CH': 'Nota Ciências Humanas',
    'NU_NOTA_LC': 'Nota Linguagens e Códigos',
    'NU_NOTA_MT': 'Nota Matemática',
    'NU_NOTA_REDACAO': 'Nota redação',
}

# %%
dic_replace_lines = {

    'Tipo de escola do Ensino Médio': {
       1:	'Não Respondeu',
       2:	'Pública',
       3:	'Privada'
    },
    'Sexo': {
        'M': 'Masculino',
        'F': 'Feminino'
    },
    'Localização (Escola)': {
        1: 'Urbana',
        2: 'Rural'   
    },
    'Faixa etária': {
        1:	'Menor de 17 anos',
        2:	'17 anos',
        3:  '18 anos',
        4:	'19 anos',
        5:	'20 anos',
        6:	'21 anos',
        7:	'22 anos',
        8:	'23 anos',
        9:	'24 anos',
        10:	'25 anos',
        11:	'Entre 26 e 30 anos',
        12:	'Entre 31 e 35 anos',
        13:	'Entre 36 e 40 anos',
        14:	'Entre 41 e 45 anos',
        15:	'Entre 46 e 50 anos',
        16:	'Entre 51 e 55 anos',
        17:	'Entre 56 e 60 anos',
        18:	'Entre 61 e 65 anos',
        19:	'Entre 66 e 70 anos',
        20:	'Maior de 70 anos'
    },
    'Cor/raça': {
        0: 'Não declarado',
        1: 'Branca',
        2: 'Preta',
        3: 'Parda',
        4: 'Amarela',
        5: 'Indígena',
        6: 'Não dispõe da informação'
    },
    'Ano de Conclusão do Ensino Médio':{
        0:	'Não informado',
        1:	'2022',
        2:	'2021',
        3:	'2020',
        4:	'2019',
        5:	'2018',
        6:	'2017',
        7:	'2016',
        8:  '2015',
        9:	'2014',
        10:	'2013',
        11:	'2012',
        12:	'2011',
        13:	'2010',
        14:	'2009',
        15: '2008',
        16:	'2007',
        17:	'Antes de 2007'
    },
    'Tipo de ensino': {
        1: 'Ensino Regular',
        2: 'Educação Especial'
    },
    'Dependência administrativa (Escola)': {
        1: 'Federal',
        2: 'Estadual',
        3: 'Municipal'
    }
}

# %%
dic_replace_lines_presenca = {

    'Presença Ciências da Natureza': {
        1: 'Presente',
        2: 'Eliminado',
        0: 'Ausente'
    },
    'Presença Ciências Humanas': {
        1: 'Presente',
        2: 'Eliminado',
        0: 'Ausente'
    },
    'Presença Linguagens e Códigos': {
        1: 'Presente',
        2: 'Eliminado',
        0: 'Ausente'
    },
    'Presença Matemática': {
        1: 'Presente',
        2: 'Eliminado',
        0: 'Ausente'
    }
}
