# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('source/base_final.csv')
df
# Out:
#       Data_Medicao  NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_  \
# 0       2010-01-31                                               16.0
# 1       2010-02-28                                                7.0
# 2       2010-03-31                                               19.0
# 3       2010-04-30                                                7.0
# 4       2010-05-31                                                4.0
# ...            ...                                                ...
# 91420   2024-03-31                                               22.0
# 91421   2024-04-30                                               20.0
# 91422   2024-05-31                                               17.0
# 91423   2024-06-30                                               23.0
# 91424   2024-07-31                                                7.0
#
#        PRECIPITACAO_TOTAL_MENSAL_AUT_mm_  \
# 0                                  100.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91425 entries, 0 to 91424
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Data_Medicao                                       91425 non-null  object
#  1   NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_  88279 non-null  float64
#  2   PRECIPITACAO_TOTAL_MENSAL_AUT_mm_                  90435 non-null  float64
#  3   PRESSAO_ATMOSFERICA_MEDIA_MENSAL_AUT_mB_           90314 non-null  float64
#  4   TEMPERATURA_MEDIA_MENSAL_AUT_C_                    90709 non-null  float64
#  5   VENTO_VELOCIDADE_MAXIMA_MENSAL_AUT_m_s_            90852 non-null  float64
#  6   VENTO_VELOCIDADE_MEDIA_MENSAL_AUT_m_s_             89722 non-null  float64
#  7   Unnamed_7                                          0 non-null      float64
# ...

# %%
df.describe().T
# Out:
#                                                      count        mean  \
# NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_  88279.0   10.872246
# PRECIPITACAO_TOTAL_MENSAL_AUT_mm_                  90435.0  110.818915
# PRESSAO_ATMOSFERICA_MEDIA_MENSAL_AUT_mB_           90314.0  966.696988
# TEMPERATURA_MEDIA_MENSAL_AUT_C_                    90709.0   23.606714
# VENTO_VELOCIDADE_MAXIMA_MENSAL_AUT_m_s_            90852.0    6.786328
# VENTO_VELOCIDADE_MEDIA_MENSAL_AUT_m_s_             89722.0    1.927097
# Unnamed_7                                              0.0         NaN
# Latitude                                           91425.0  -15.781620
# Longitude                                          91425.0  -47.844919
# Altitude                                           91425.0  416.498535
#
#                                                           std         min  \
# NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_    7.555116    0.000000
# ...

# %%
df.columns
# Out:
# Index(['Data_Medicao', 'NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_',
#        'PRECIPITACAO_TOTAL_MENSAL_AUT_mm_',
#        'PRESSAO_ATMOSFERICA_MEDIA_MENSAL_AUT_mB_',
#        'TEMPERATURA_MEDIA_MENSAL_AUT_C_',
#        'VENTO_VELOCIDADE_MAXIMA_MENSAL_AUT_m_s_',
#        'VENTO_VELOCIDADE_MEDIA_MENSAL_AUT_m_s_', 'Unnamed_7', 'Nome',
#        'Codigo_Estacao', 'Latitude', 'Longitude', 'Altitude', 'Situacao',
#        'Data_Inicial', 'Data_Final', 'Periodicidade_da_Medicao'],
#       dtype='object')

# %%
#df_limpo = df.dropna()

#df_limpo.to_csv('source/df_limpo.csv', index=False)
# Out:
# Empty DataFrame
# Columns: [Data_Medicao, NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_, PRECIPITACAO_TOTAL_MENSAL_AUT_mm_, PRESSAO_ATMOSFERICA_MEDIA_MENSAL_AUT_mB_, TEMPERATURA_MEDIA_MENSAL_AUT_C_, VENTO_VELOCIDADE_MAXIMA_MENSAL_AUT_m_s_, VENTO_VELOCIDADE_MEDIA_MENSAL_AUT_m_s_, Unnamed_7, Nome, Codigo_Estacao, Latitude, Longitude, Altitude, Situacao, Data_Inicial, Data_Final, Periodicidade_da_Medicao]
# Index: []

# %%
df = df.fillna(0)
df
# Out:
#       Data_Medicao  NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_  \
# 0       2010-01-31                                               16.0
# 1       2010-02-28                                                7.0
# 2       2010-03-31                                               19.0
# 3       2010-04-30                                                7.0
# 4       2010-05-31                                                4.0
# ...            ...                                                ...
# 91420   2024-03-31                                               22.0
# 91421   2024-04-30                                               20.0
# 91422   2024-05-31                                               17.0
# 91423   2024-06-30                                               23.0
# 91424   2024-07-31                                                7.0
#
#        PRECIPITACAO_TOTAL_MENSAL_AUT_mm_  \
# 0                                  100.2
# ...

# %%
df.drop(columns=['Unnamed_7'], inplace=True)

# %%
df.columns
# Out:
# Index(['Data_Medicao', 'NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_',
#        'PRECIPITACAO_TOTAL_MENSAL_AUT_mm_',
#        'PRESSAO_ATMOSFERICA_MEDIA_MENSAL_AUT_mB_',
#        'TEMPERATURA_MEDIA_MENSAL_AUT_C_',
#        'VENTO_VELOCIDADE_MAXIMA_MENSAL_AUT_m_s_',
#        'VENTO_VELOCIDADE_MEDIA_MENSAL_AUT_m_s_', 'Nome', 'Codigo_Estacao',
#        'Latitude', 'Longitude', 'Altitude', 'Situacao', 'Data_Inicial',
#        'Data_Final', 'Periodicidade_da_Medicao'],
#       dtype='object')

# %%
colunas = ['Situacao', 'Data_Inicial', 'Data_Final', 'Periodicidade_da_Medicao']
df.drop(columns=colunas, inplace=True)

df.to_csv('base_final_tratada.csv', index=False)
