# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('base_final_tratada.csv')
df
# Out:
#       Data_Medicao  NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_  \
# 0       2010-01-31                                               16.0
# 1       2010-02-28                                                7.0
# 2       2010-03-31                                               19.0
# 3       2010-04-30                                                7.0
# 4       2010-05-31                                                4.0
# ...            ...                                                ...
# 91420   2024-03-31                                               22.0
# 91421   2024-04-30                                               20.0
# 91422   2024-05-31                                               17.0
# 91423   2024-06-30                                               23.0
# 91424   2024-07-31                                                7.0
#
#        PRECIPITACAO_TOTAL_MENSAL_AUT_mm_  \
# 0                                  100.2
# ...

# %%
df.describe().T
# Out:
#                                                      count        mean  \
# NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_  91425.0   10.498124
# PRECIPITACAO_TOTAL_MENSAL_AUT_mm_                  91425.0  109.618907
# PRESSAO_ATMOSFERICA_MEDIA_MENSAL_AUT_mB_           91425.0  954.949651
# TEMPERATURA_MEDIA_MENSAL_AUT_C_                    91425.0   23.421836
# VENTO_VELOCIDADE_MAXIMA_MENSAL_AUT_m_s_            91425.0    6.743795
# VENTO_VELOCIDADE_MEDIA_MENSAL_AUT_m_s_             91425.0    1.891200
# Latitude                                           91425.0  -15.781620
# Longitude                                          91425.0  -47.844919
# Altitude                                           91425.0  416.498535
#
#                                                           std        min  \
# NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_    7.683959   0.000000
# PRECIPITACAO_TOTAL_MENSAL_AUT_mm_                  113.049072   0.000000
# ...

# %%
df.columns
# Out:
# Index(['Data_Medicao', 'NUMERO_DE_DIAS_COM_PRECIP_PLUV_MENSAL_AUT_n_mero_',
#        'PRECIPITACAO_TOTAL_MENSAL_AUT_mm_',
#        'PRESSAO_ATMOSFERICA_MEDIA_MENSAL_AUT_mB_',
#        'TEMPERATURA_MEDIA_MENSAL_AUT_C_',
#        'VENTO_VELOCIDADE_MAXIMA_MENSAL_AUT_m_s_',
#        'VENTO_VELOCIDADE_MEDIA_MENSAL_AUT_m_s_', 'Nome', 'Codigo_Estacao',
#        'Latitude', 'Longitude', 'Altitude'],
#       dtype='object')

# %%
df['Data_Medicao'] = pd.to_datetime(df['Data_Medicao'])


df['Ano'] = df['Data_Medicao'].dt.year

df_agrupado = df.groupby('Ano')['PRECIPITACAO_TOTAL_MENSAL_AUT_mm_'].sum().reset_index()

# %%
plt.figure(figsize=(10, 6))
plt.figure(figsize=(10, 6))
plt.plot(df_agrupado['Ano'], df_agrupado['PRECIPITACAO_TOTAL_MENSAL_AUT_mm_'], marker='o', linestyle='-', color='b')
plt.title('Precipitação Total Mensal por Ano')
plt.xlabel('Ano')
plt.ylabel('Precipitação Total (mm)')
plt.grid(True)
plt.xticks(df_agrupado['Ano'])
plt.tight_layout()
plt.show()

# %%
df['Data_Medicao'] = pd.to_datetime(df['Data_Medicao'])
df['Ano'] = df['Data_Medicao'].dt.year
df_2024 = df[df['Ano'] == 2024].copy() 
df_2024.loc[:, 'Mês'] = df_2024['Data_Medicao'].dt.month
df_agrupado = df_2024.groupby('Mês')['PRECIPITACAO_TOTAL_MENSAL_AUT_mm_'].sum().reset_index()

# %%
df_agrupado = df_2024.groupby('Mês')['PRECIPITACAO_TOTAL_MENSAL_AUT_mm_'].sum().reset_index()
plt.figure(figsize=(10, 6))
plt.plot(df_agrupado['Mês'], df_agrupado['PRECIPITACAO_TOTAL_MENSAL_AUT_mm_'], marker='o', linestyle='-', color='b')
plt.title('Precipitação Total Mensal em 2024')
plt.xlabel('Mês')
plt.ylabel('Precipitação Total (mm)')
plt.grid(True)
plt.xticks(df_agrupado['Mês'], 
           ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 8
#       6 plt.ylabel('Precipitação Total (mm)')
#       7 plt.grid(True)
# ----> 8 plt.xticks(df_agrupado['Mês'],
#       9            ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
#      10 plt.tight_layout()
#      11 plt.show()
#
# File c:\Users\lucia\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2229, in xticks(ticks, labels, minor, **kwargs)
#    2227         l._internal_update(kwargs)
#    2228 else:
# -> 2229     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    2231 return locs, labels_out
#
# File c:\Users\lucia\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['PRECIPITACAO_TOTAL_MENSAL_AUT_mm_'], bins=20, edgecolor='black')
plt.title('Distribuição da Precipitação Total Mensal')
plt.xlabel('Precipitação Total (mm)')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %%
df['Data_Medicao'] = pd.to_datetime(df['Data_Medicao'])

df['Ano'] = df['Data_Medicao'].dt.year

df_filtrado = df[df['TEMPERATURA_MEDIA_MENSAL_AUT_C_'] > 0]

df_temperaturas = df_filtrado.groupby('Ano').agg({
    'TEMPERATURA_MEDIA_MENSAL_AUT_C_': ['max', 'min']
}).reset_index()

df_temperaturas.columns = ['Ano', 'Temperatura_Maxima', 'Temperatura_Minima']

print(df_temperaturas.head())
# Out:
#     Ano  Temperatura_Maxima  Temperatura_Minima
# 0  2010                31.4                 7.8
# 1  2011                31.0                 6.9
# 2  2012                32.5                 7.0
# 3  2013                31.5                 7.7
# 4  2014                31.0                 7.9

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_temperaturas['Ano'], df_temperaturas['Temperatura_Maxima'], marker='o', linestyle='-', color='red', label='Temperatura Máxima')
plt.plot(df_temperaturas['Ano'], df_temperaturas['Temperatura_Minima'], marker='o', linestyle='-', color='blue', label='Temperatura Mínima')
plt.title('Temperaturas Máximas e Mínimas ao Longo dos Anos')
plt.xlabel('Ano')
plt.ylabel('Temperatura Média (°C)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df['Data_Medicao'] = pd.to_datetime(df['Data_Medicao'])
df['Ano'] = df['Data_Medicao'].dt.year
df_max_temp = df.groupby(['Latitude', 'Longitude']).agg({
    'TEMPERATURA_MEDIA_MENSAL_AUT_C_': 'max'
}).reset_index()
print(df_max_temp.head())
# Out:
#     Latitude  Longitude  TEMPERATURA_MEDIA_MENSAL_AUT_C_
# 0 -33.742222 -53.372222                             24.0
# 1 -32.534722 -53.375833                             24.7
# 2 -32.078889 -52.167778                             25.2
# 3 -31.802500 -52.407222                             25.0
# 4 -31.403333 -52.700833                             23.0
